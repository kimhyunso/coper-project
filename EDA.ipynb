# %%
import pandas as pd
import Preprocessing as prep
chim_df = pd.read_csv('./데이터/침착맨_videos.csv', encoding='utf-8', engine='python')
chim_df.uploaded_at = pd.to_datetime(chim_df.uploaded_at)


# chim_df.sort_values(by='views_count', ascending=False).head(10)
# chim_df.sort_values(by='like_count', ascending=False).head(10)

# chim_df.description = chim_df.description.apply(prep.extract_hashtags)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()

plt.rcParams['figure.figsize'] = (11, 7)

sns.lineplot(x=chim_df.uploaded_at, y=chim_df.views_count)
plt.show()

# %%
sns.lineplot(x=chim_df.uploaded_at, y=chim_df.sort_values(by='views_count', ascending=False).loc[chim_df.uploaded_at.dt.year == 2016].views_count)
plt.show()

# %%
sns.lineplot(x=chim_df.uploaded_at, y=chim_df.sort_values(by='views_count', ascending=False).loc[chim_df.uploaded_at.dt.year == 2017].views_count)
plt.show()

# %%
sns.lineplot(x=chim_df.uploaded_at, y=chim_df.sort_values(by='views_count', ascending=False).loc[chim_df.uploaded_at.dt.year == 2018].views_count)
plt.show()

# %%
sns.lineplot(x=chim_df.uploaded_at, y=chim_df.sort_values(by='views_count', ascending=False).loc[chim_df.uploaded_at.dt.year == 2019].views_count)
plt.show()

# %%
sns.lineplot(x=chim_df.uploaded_at, y=chim_df.sort_values(by='views_count', ascending=False).loc[chim_df.uploaded_at.dt.year == 2020].views_count)
plt.show()

# %%
sns.lineplot(x=chim_df.uploaded_at, y=chim_df.sort_values(by='views_count', ascending=False).loc[chim_df.uploaded_at.dt.year == 2022].views_count)
plt.show()

# %%
chim_df.sort_values(by='views_count', ascending=False).loc[chim_df.uploaded_at.dt.year == 2022].head(10)
# Out:
#         video_id  category_id  category_name                    title  \
# 227  kOl27s1mgrg           24  Entertainment           더 놀라운 이왜진? 월드컵
# 222  hVE_Qc6PjoA           24  Entertainment       금연 23일차에 하는 담배 월드컵
# 217  a6470TMHpFc           24  Entertainment           매력있는 악역/악당 월드컵
# 199  tAEUm8sxbgU           24  Entertainment             통닭천사의 돼지 파스타
# 215  31FwmCAEJww           24  Entertainment           상남자특) 순댓국 특 먹음
# 167  QsuhIGOXxfs           24  Entertainment           과학으로 본 주호민의 재즈
# 195  PBUBzuGPoVY           24  Entertainment   주변에서 만날 수 있는 고대 이집트 1편
# 234  leOZrOGHj6U           24  Entertainment            최고의 겨울 간식 월드컵
# 119  -xICFR9I6Ls           24  Entertainment        전무님과 (하나도 빼지)마라샹궈
# 174  aB8Xgn6JKXw           24  Entertainment  [ENG] 침펄인물사전 | 2장 백예린 편
#
#      views_count  like_count               uploaded_at                tags
# 227      4146183       18213 2022-01-24 10:00:30+00:00    #김풍 #이상형월드컵 #이왜진
# ...

# %%
sns.lineplot(x=chim_df.uploaded_at, y=chim_df.sort_values(by='views_count', ascending=False).loc[chim_df.uploaded_at.dt.year == 2023].views_count)
plt.show()

# %%
chim_df.sort_values(by='views_count', ascending=False).loc[chim_df.uploaded_at.dt.year == 2023].head(10)
# Out:
#        video_id  category_id  category_name  \
# 53  SP-LJqVgQuw           24  Entertainment
# 44  5l5OUajgNOA           24  Entertainment
# 49  cspfdOFcOsE           24  Entertainment
# 13  FwAf4mbaVis           24  Entertainment
# 40  K3uVJDoFuhw           24  Entertainment
# 47  8PPUFdfzca0           24  Entertainment
# 55  RRnO-9xfJY8           24  Entertainment
# 54  K6Pfi0yLav8           24  Entertainment
# 45  2dmZLhS-inY           24  Entertainment
# 51  z_OdvenYnAs           24  Entertainment
#
#                                          title  views_count  like_count  \
# 53                               [ENG] 뉴진스 초대석      3878769       59017
# 44                                       안녕 구찌      1781399       19141
# 49                    한국 좀비사태 발생시 필요한 현실능력 월드컵      1703317       11982
# 13                                사이좋게 나눠먹는 분식      1561730       17855
# 40             양정무 교수님의 '세상에서 가장 비싼 그림 이야기' 특강      1416421       12785
# ...
